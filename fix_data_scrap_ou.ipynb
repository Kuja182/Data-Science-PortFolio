# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Arreglando Óptica universitaria, primero LC y liquidos

# %%
data_lc_1_d = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/diarias_ou_1.csv", index_col=0)
data_lc_2_d = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/diarias_ou_2.csv", index_col=0)
data_lc_1_m = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/mensuales_ou_1.csv", index_col=0)
data_lc_2_m = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/mensuales_ou_2.csv", index_col=0)
data_lc_q = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/quincenales_ou.csv", index_col=0)
data_liquidos_1 = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/boston_ou.csv", index_col=0)
data_liquidos_2 = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/disop_ou.csv", index_col=0)
data_liquidos_3 = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/opti-free_ou.csv", index_col=0)
data_liquidos_4 = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/renu_ou.csv", index_col=0)
data_liquidos_5 = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/systane_ou.csv", index_col=0)
data_liquidos_6 = pd.read_csv("./data/csv_scrap/ou/lc y liquidos/lentsoft_liquidos_ou.csv", index_col=0)

# %%
data_lc_1_d
# Out:
#                                       nombre_completo           categoria  \
# 0                      PRECISION1™ 30 UNIDADES DIARIA  Lentes de Contacto
# 1   LENTSOFT DIARIA HIDROGEL ASTIGMATISMO 30 UNIDADES  Lentes de Contacto
# 2       DAILIES™ AQUACOMFORT™ PLUS 30 UNIDADES DIARIA  Lentes de Contacto
# 3       DAILIES™ AQUACOMFORT™ PLUS 90 UNIDADES DIARIA  Lentes de Contacto
# 4   DAILIES™ AQUACOMFORT™ PLUS MULTIFOCAL 30 UNIDA...  Lentes de Contacto
# 5                DAILIES™ TOTAL1™ 30 UNIDADES DIARIAS  Lentes de Contacto
# 6                DAILIES™ TOTAL1™ 90 UNIDADES DIARIAS  Lentes de Contacto
# 7                LENTSOFT DIARIA SILICONA 30 UNIDADES  Lentes de Contacto
# 8                 ACUVUE® OASYS MAX 1-Day 30 UNIDADES  Lentes de Contacto
# 9         PRECISION1™ ASTIGMATISMO 30 UNIDADES DIARIA  Lentes de Contacto
# 10        PRECISION1™ ASTIGMATISMO 90 UNIDADES DIARIA  Lentes de Contacto
# 11  1-DAY™ ACUVUE™ OASYS ASTIGMATISMO 90 UNIDADES ...  Lentes de Contacto
# 12    LENTSOFT DIARIA HIDROGEL MULTIFOCAL 30 UNIDADES  Lentes de Contacto
# 13                     PRECISION1™ 90 UNIDADES DIARIA  Lentes de Contacto
# 14                      MyDay™ MULTIFOCAL 30 UNIDADES  Lentes de Contacto
# 15  DAILIES™ AQUACOMFORT™ PLUS ASTIGMATISMO 90 UNI...  Lentes de Contacto
# 16  DAILIES™ AQUACOMFORT™ PLUS MULTIFOCAL 90 UNIDA...  Lentes de Contacto
# 17      LENTSOFT DIARIA CONFORT+ SILICONA 30 UNIDADES  Lentes de Contacto
# 18  LENTSOFT DIARIA CONFORT+ SILICONA ASTIGMATISMO...  Lentes de Contacto
# 19  LENTSOFT DIARIA CONFORT+ SILICONA MULTIFOCAL 3...  Lentes de Contacto
# 20  DAILIES™ TOTAL1™ ASTIGMATISMO 30 UNIDADES DIARIAS  Lentes de Contacto
# 21  DAILIES™ TOTAL1™ ASTIGMATISMO 90 UNIDADES DIARIAS  Lentes de Contacto
# 22    ACUVUE® OASYS MAX MULTIFOCAL 1-Day 30 UNIDADES   Lentes de Contacto
# 23  LENTSOFT DIARIA HIDROGEL 90 UNIDADES (3x30 UNI...  Lentes de Contacto
#
#       producto remplazo  precio
# 0   Precision1  Diarias    22.5
# 1     Lentsoft  Diarias    25.0
# 2      Dailies  Diarias    26.0
# 3      Dailies  Diarias    75.0
# 4      Dailies  Diarias    33.0
# 5     total 30  Diarias    33.5
# 6     total 30  Diarias    80.0
# 7     Lentsoft  Diarias    17.0
# 8       Acuvue  Diarias    35.0
# 9   Precision1  Diarias    34.0
# 10  Precision1  Diarias    95.0
# 11      Acuvue  Diarias    80.0
# 12    Lentsoft  Diarias    29.0
# 13  Precision1  Diarias    67.0
# 14   Biofinity  Diarias    49.0
# 15     Dailies  Diarias    85.0
# 16     Dailies  Diarias    95.0
# 17    Lentsoft  Diarias    19.0
# 18    Lentsoft  Diarias    31.0
# 19    Lentsoft  Diarias    33.0
# 20    total 30  Diarias    49.0
# 21    total 30  Diarias   127.0
# 22      Acuvue  Diarias    44.0
# 23    Lentsoft  Diarias    44.0

# %%
data_lc_1_d["remplazo"] = data_lc_1_d["remplazo"] = "Diarias"
data_lc_1_d["categoria"] = data_lc_1_d["categoria"] = "Lentes de Contacto"
data_lc_2_d["remplazo"] = data_lc_2_d["remplazo"] = "Diarias"
data_lc_2_d["categoria"] = data_lc_2_d["categoria"] = "Lentes de Contacto"
data_lc_1_m["remplazo"] = data_lc_1_m["remplazo"] = "Mensuales"
data_lc_1_m["categoria"] = data_lc_1_m["categoria"] = "Lentes de Contacto"
data_lc_2_m["remplazo"] = data_lc_1_m["remplazo"] = "Mensuales"
data_lc_2_m["categoria"] = data_lc_1_m["categoria"] = "Lentes de Contacto"
data_lc_q["remplazo"] = data_lc_q["remplazo"] = "Quincenal"
data_lc_q["categoria"] = data_lc_q["categoria"] = "Lentes de Contacto"

# %%
data_liquidos_1.drop(["reemplazo"], axis=1, inplace=True)
data_liquidos_2.drop(["reemplazo"], axis=1, inplace=True)
data_liquidos_3.drop(["reemplazo"], axis=1, inplace=True)
data_liquidos_4.drop(["reemplazo"], axis=1, inplace=True)
data_liquidos_5.drop(["reemplazo"], axis=1, inplace=True)
data_liquidos_6.drop(["reemplazo"], axis=1, inplace=True)

# %%
data_liquidos_1
# Out:
#                             nombre_completo categoria producto  precio
# 0                   BOSTON LIMPIADOR 30 ml.  Líquidos   Boston     7.5
# 1                     BOSTON SIMPLUS 120 ML  Líquidos   Boston     9.0
# 2  HUMECTANTE ACONDICIONADOR BOSTON 120 ml.  Líquidos   Boston     8.5

# %%
data_tot_liqu_ou = pd.concat([data_liquidos_1,data_liquidos_2,data_liquidos_3,data_liquidos_4,data_liquidos_5,data_liquidos_6],axis=0)

# %%
data_tot_liqu_ou
# Out:
#                                      nombre_completo categoria   producto  \
# 0                            BOSTON LIMPIADOR 30 ml.  Líquidos     Boston
# 1                              BOSTON SIMPLUS 120 ML  Líquidos     Boston
# 2           HUMECTANTE ACONDICIONADOR BOSTON 120 ml.  Líquidos     Boston
# 0                            HIDRO HEALTH SiH 360 ML  Líquidos      Disop
# 1                         ACUAISS BAÑO OCULAR 100 ML  Líquidos      Disop
# 2                        ENZIMAS NACLENS 10 TABLETAS  Líquidos      Disop
# 0                          OPTI-FREE EXPRESS 355 ML.  Líquidos  Opti-Free
# 1                         OPTI-FREE PUREMOIST 300 ML  Líquidos  Opti-Free
# 0                              RENU MULTIPLUS 500 ml  Líquidos       Renu
# 0  SYSTANE™ TOALLITAS PARA LIMPIEZA OCULAR HIPOAL...  Líquidos    Systane
# 1  SYSTANE™ COMPLETE - GOTAS OFTALOMICAS SIN CONS...  Líquidos    Systane
# 2                              SYSTANE™ ULTRA 10 ml.  Líquidos    Systane
# 3  SYSTANE™ ULTRA MONODOSIS 30 UNIDADES SIN CONSE...  Líquidos    Systane
# 4                          SYSTANE™ GEL DROPS 10 ML.  Líquidos    Systane
# 0                     LENTSOFT SOLUCIÓN ÚNICA 360 ML  Líquidos   Lentsoft
# 1                   LENTSOFT MONODOSIS (20 X 0.35ml)  Líquidos   Lentsoft
# 2                            LENTSOFT 100 ML (VIAJE)  Líquidos   Lentsoft
# 3                    LENTSOFT GOTAS HUMECTANTES 6ML   Líquidos   Lentsoft
# 4          LENTSOFT SOLUCIÓN UNICA HIDRATANTE 360 ML  Líquidos   Lentsoft
# 5          LENTSOFT SOLUCIÓN ÚNICA HIDRATANTE 100 ML  Líquidos   Lentsoft
# 6                  LENTSOFT SOLUCIÓN PERÓXIDO 250 ML  Líquidos   Lentsoft
# 7                    LENTSOFT SOLUCION SALINA 360 ML  Líquidos   Lentsoft
#
#    precio
# 0    7.50
# 1    9.00
# 2    8.50
# 0    7.50
# 1    5.00
# 2    6.25
# 0    8.90
# 1   13.50
# 0   10.50
# 0   15.00
# 1   13.00
# 2   11.00
# 3   11.00
# 4   11.00
# 0    4.50
# 1    5.50
# 2    2.50
# 3    4.50
# 4    6.50
# 5    3.50
# 6    6.50
# 7    3.00

# %%
data_tot_liqu_ou.reset_index(inplace=True)

# %%
data_tot_liqu_ou.drop("index",axis=1,inplace=True)
data_tot_liqu_ou = data_tot_liqu_ou.rename(columns={"nombre_completo":"Nombre completo",
                                                "categoria":"Categoria",
                                                "producto":"Producto",
                                                "precio":"Precio"})

# %%
data_tot_liqu_ou["Empresa"] = "Óptica Universitaria"

data_tot_liqu_ou = data_tot_liqu_ou[["Empresa","Nombre completo","Categoria","Producto","Precio"]]

# %%
data_tot_liqu_ou.to_csv(".\Data\data_tot_liqu_ou.csv", index=False)

# %%
data_tot_lc_ou = pd.concat([data_lc_1_d,data_lc_1_m,data_lc_2_d,data_lc_2_m,data_lc_q],axis=0)

# %%
data_tot_lc_ou.reset_index(inplace=True)
data_tot_lc_ou.drop("index",axis=1,inplace=True)

# %%
data_tot_lc_ou = data_tot_lc_ou.rename(columns={'remplazo': 'Reemplazo',
                                                "nombre_completo":"Nombre completo",
                                                "categoria":"Categoria",
                                                "producto":"Producto",
                                                "precio":"Precio"})

# %%
data_tot_lc_ou["Empresa"] = "Óptica Universitaria"

data_tot_lc_ou = data_tot_lc_ou[["Empresa","Nombre completo","Categoria","Producto","Reemplazo","Precio"]]

# %%
data_tot_lc_ou.to_csv(".\Data\data_tot_lc_ou.csv", index=False)

# %% [markdown]
# Arregladas las LC y los liquidos, ahora tocan las gafas.

# %%
data_gafa_1 = pd.read_csv("./data/csv_scrap/ou/gafas/mont_crist_ou_1.csv", index_col=0)
data_gafa_2 = pd.read_csv("./data/csv_scrap/ou/gafas/mont_crist_ou_2.csv", index_col=0)
data_gafa_3 = pd.read_csv("./data/csv_scrap/ou/gafas/mont_crist_ou_3.csv", index_col=0)
data_gafa_4 = pd.read_csv("./data/csv_scrap/ou/gafas/mont_crist_ou_4.csv", index_col=0)
data_gafa_5 = pd.read_csv("./data/csv_scrap/ou/gafas/mont_crist_ou_5.csv", index_col=0)
data_gafa_6 = pd.read_csv("./data/csv_scrap/ou/gafas/mont_crist_ou_6.csv", index_col=0)

# %%
data_gafas = pd.concat([data_gafa_1,data_gafa_2,data_gafa_3,data_gafa_4,data_gafa_5,data_gafa_6],axis=0)

# %%
data_gafas.drop("remplazo", inplace=True, axis=1)

# %%
data_gafas["categoria"] = data_gafas["categoria"] = "Ofertas montura + cristales"

# %%
data_gafas
# Out:
#                     nombre_completo                    categoria  \
# 0                      BEO S179 C01  Ofertas montura + cristales
# 1                        BEO 526 C1  Ofertas montura + cristales
# 2               KYPERS TONYA TNY001  Ofertas montura + cristales
# 3             KYPERS ENRIQUE ERQ001  Ofertas montura + cristales
# 4                      BEO S182 C02  Ofertas montura + cristales
# ..                              ...                          ...
# 34            POLAROID PLD D484 807  Ofertas montura + cristales
# 35              CARRERA CA 8885 BLX  Ofertas montura + cristales
# 0             POLAROID PLD D485 KJ1  Ofertas montura + cristales
# 1        TOMMY HILFIGER TH 2008 GWM  Ofertas montura + cristales
# 2   TOMMY HILFIGER TH 1981 S S3S IR  Ofertas montura + cristales
#
#           producto  precio
# 0              BeO    49.0
# 1              BeO    49.0
# 2           Kypers    49.0
# 3           Kypers    49.0
# 4              BeO    49.0
# ..             ...     ...
# 34        Polaroid    69.0
# 35         Carrera    79.0
# 0         Polaroid    69.0
# 1   Tommy Hilfiger    89.0
# 2   Tommy Hilfiger    89.0
#
# [183 rows x 4 columns]

# %%
data_gafas["Empresa"] = "Óptica Universitaria"

# %%
data_gafas = data_gafas.rename(columns={"nombre_completo":"Nombre completo",
                                                "categoria":"Categoria",
                                                "producto":"Producto",
                                                "precio":"Precio"})

# %%
data_gafas = data_gafas[["Empresa","Nombre completo","Categoria","Producto","Precio"]]

# %%
data_gafas.to_csv(".\Data\data_gafas.csv", index=False)
