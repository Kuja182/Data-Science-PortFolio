# %%
import hashlib
import requests
import pandas as pd
import datetime

# %%
timestamp = datetime.datetime.now().strftime('%Y-%m-%d%H:%M:%S')

# %%
import hashlib
import requests
import pandas as pd

def llamar_api(timestamp,offset):
    params = {'ts': timestamp,  
        'limit': 100,
        'offset': offset,
        };

    url = 'https://americas.api.riotgames.com/lor/ranked/v1/leaderboards?api_key=RGAPI-272fafbd-8817-454c-be54-2d0228278d65'

    res = requests.get(url)
    respuesta_json = res.json()
    return respuesta_json

# %%
dict_names = llamar_api(timestamp,100)

# %%
dict_names["players"]
# Out:
# [{'name': 'Kuako', 'rank': 0, 'lp': 2011.0},
#  {'name': 'Drisoth', 'rank': 1, 'lp': 2000.0},
#  {'name': 'TTVNicMakesPlays', 'rank': 2, 'lp': 1859.0},
#  {'name': 'infinipatrons', 'rank': 3, 'lp': 1814.0},
#  {'name': 'fitze', 'rank': 4, 'lp': 1779.0},
#  {'name': 'GrandpaRoji', 'rank': 5, 'lp': 1767.0},
#  {'name': 'mtucks', 'rank': 6, 'lp': 1696.0},
#  {'name': 'LiP', 'rank': 7, 'lp': 1659.0},
#  {'name': 'AJTehPro', 'rank': 8, 'lp': 1645.0},
#  {'name': 'Da Tank Buster', 'rank': 9, 'lp': 1642.0},
#  {'name': 'Ichiran Ramen', 'rank': 10, 'lp': 1568.0},
#  {'name': 'eMOEtional', 'rank': 11, 'lp': 1502.0},
#  {'name': 'Rusticles', 'rank': 12, 'lp': 1501.0},
#  {'name': 'XxWhatAmIxX', 'rank': 13, 'lp': 1405.0},
#  {'name': '毛茛公主', 'rank': 14, 'lp': 1339.0},
#  {'name': 'ptash', 'rank': 15, 'lp': 1286.0},
#  {'name': 'MajiinBae', 'rank': 16, 'lp': 1266.0},
#  {'name': 'GrayMerchant47', 'rank': 17, 'lp': 1242.0},
#  {'name': 'RattlingBones', 'rank': 18, 'lp': 1205.0},
# ...

# %%
def json_to_df(respuesta_json):
    name_dict = {"name": [],
                "rank": [],
                "lp": []
                }

    for elem in respuesta_json["players"]:
        name_dict['name'].append(elem.get("name"))
        name_dict['rank'].append(elem.get('rank'))
        name_dict['lp'].append(elem.get('lp'))
    
    df_results = pd.DataFrame(name_dict)
    return df_results

# %%
data_1 = json_to_df(dict_names)

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5699 non-null   object
#  1   rank    5699 non-null   int64
#  2   lp      5699 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 133.7+ KB

# %%
df_results = pd.DataFrame({'id':[],
                            'name':[],
                            'picture_url':[]})

for n_requests in range(3):
    response = llamar_api(timestamp,priv_key,pub_key, n_requests * 100)
    df = json_to_df(response)

    df_results = pd.concat([df_results, df], axis=0)

df_results.reset_index(drop=True, inplace=True)
df_results
