# %% [markdown]
# Primero con las LC, categoria-producto-remplazo-precio

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np


pd.set_option('max_colwidth', 800)

# %%
url = "https://www.afflelou.es/lentillas/"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
html = response.content
soup = bs(html, 'html.parser')

# %%
soup.find_all("div",class_="ProductsGridstyled__ProductsGridStyled-sc-10ok271-0 bUZDTm")
# Out:
# [<div class="ProductsGridstyled__ProductsGridStyled-sc-10ok271-0 bUZDTm"><div class="ProductsGridstyled__FiltersStyled-sc-10ok271-2 bJzgFm FiltersHeader" id="filters" style="height:2.6rem"><div class="FiltersHeader-Wrap cmsBlock" style="height:2.6rem"><div class="FiltersHeader-Options center"><div class="FiltersHeader-Options-Wrap center"><span class="FiltersHeader-Options-Span" id="filter"><span>Filtros</span><span class="Iconstyled__IconStyles-sc-199mfc0-0 bqsKgs chevron"><svg fill="none" height="1rem" viewbox="0 0 20 20" width="1rem" xmlns="http://www.w3.org/2000/svg"><path d="M14 7L6 7L10 13L14 7Z" fill="black" stroke="black" stroke-linecap="square" stroke-linejoin="round"></path></svg></span></span></div><div class="FiltersHeader-Options-Wrap center"><span class="FiltersHeader-Options-Span" id="sort"><span>Ordenar 402 Modelos</span><span class="Iconstyled__IconStyles-sc-199mfc0-0 bqsKgs chevron"><svg fill="none" height="1rem" viewbox="0 0 20 20" width="1rem" xmlns="http://www.w3.org/2000/svg"><path d="M14 7L6 7L10 13L14 7Z" fill="black" stroke="black" stroke-linecap="square" stroke-linejoin="round"></path></svg></span></span></div></div><div class="FiltersHeader-Custom-Right-Views"><span class="Iconstyled__IconStyles-sc-199mfc0-0 bqsKgs"><svg fill="none" height="1rem" viewbox="0 0 20 20" width="1rem" xmlns="http://www.w3.org/2000/svg"><rect fill="#000000" height="16" rx="2" width="16" x="2" y="2"></rect></svg></span><span class="Iconstyled__IconStyles-sc-199mfc0-0 bqsKgs"><svg fill="none" height="1rem" viewbox="0 0 20 20" width="1rem" xmlns="http://www.w3.org/2000/svg"><rect fill="#828283" height="7.2" rx="2" width="7.2" x="10.8" y="2"></rect><rect fill="#828283" height="7.2" rx="2" width="7.2" x="10.8" y="10.8"></rect><rect fill="#828283" height="7.2" rx="2" width="7.2" x="2" y="10.8"></rect><rect fill="#828283" height="7.2" rx="2" width="7.2" x="2" y="2"></rect></svg></span></div></div></div><div class="ProductsGridstyled__ProductsGridLargeStyled-sc-10ok271-1 cACmWR ProdcutsGrid-Content"><div class="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 kDLTuk ProductCard"><div class="ProductCard-Header"><div class="ProductCard-Header-Fav"></div></div><a class="ProductCard-Image center cover" href="/es/bay-mng5675-es" hreflang="es-es" rel="alternate" target=""><img alt="BAY NARANJA" class="imgCover" loading="lazy" src="https://d2wzbrvl8utv4v.cloudfront.net/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/m/n/mng567520_1.png"/></a><div class="ProductCard-Info"><a class="ProductCard-Info-Line1" href="/es/bay-mng5675-es" hreflang="es-es" rel="alternate" target=""><p class="ProductCard-Info-Line1-Title">BAY</p><div class="ProductCard-Info-Line1-Price"><label>104,90 €</label></div></a><div class="ProductCard-Info-Line2"><p class="ProductCard-Info-Line2-Brand"></p><div class="ProductCard-Info-Colors"><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#633a34"></div></div><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#ff8000"></div></div></div></div></div></div><div class="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 kDLTuk ProductCard"><div class="ProductCard-Header"><div class="ProductCard-Header-Fav"></div></div><a class="ProductCard-Image center cover" href="/es/hyacinth-vtg5623-es" hreflang="es-es" rel="alternate" target=""><img alt="HYACINTH ROSA" class="imgCover" loading="lazy" src="https://d2wzbrvl8utv4v.cloudfront.net/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/v/t/vtg562326.png"/></a><div class="ProductCard-Info"><a class="ProductCard-Info-Line1" href="/es/hyacinth-vtg5623-es" hreflang="es-es" rel="altern ...

# %%
zona = soup.find_all("div",class_="ProdcutsGrid-Content")
for zonas in zona:
    print(zonas)
# Out:
# <div class="ProductsGridstyled__ProductsGridLargeStyled-sc-10ok271-1 cACmWR ProdcutsGrid-Content"><div class="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 kDLTuk ProductCard"><div class="ProductCard-Header"><div class="ProductCard-Header-Fav"></div></div><a class="ProductCard-Image center cover" href="/es/bay-mng5675-es" hreflang="es-es" rel="alternate" target=""><img alt="BAY NARANJA" class="imgCover" loading="lazy" src="https://d2wzbrvl8utv4v.cloudfront.net/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/m/n/mng567520_1.png"/></a><div class="ProductCard-Info"><a class="ProductCard-Info-Line1" href="/es/bay-mng5675-es" hreflang="es-es" rel="alternate" target=""><p class="ProductCard-Info-Line1-Title">BAY</p><div class="ProductCard-Info-Line1-Price"><label>104,90 €</label></div></a><div class="ProductCard-Info-Line2"><p class="ProductCard-Info-Line2-Brand"></p><div class="ProductCard-Info-Colors"><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#633a34"></div></div><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#ff8000"></div></div></div></div></div></div><div class="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 kDLTuk ProductCard"><div class="ProductCard-Header"><div class="ProductCard-Header-Fav"></div></div><a class="ProductCard-Image center cover" href="/es/hyacinth-vtg5623-es" hreflang="es-es" rel="alternate" target=""><img alt="HYACINTH ROSA" class="imgCover" loading="lazy" src="https://d2wzbrvl8utv4v.cloudfront.net/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/v/t/vtg562326.png"/></a><div class="ProductCard-Info"><a class="ProductCard-Info-Line1" href="/es/hyacinth-vtg5623-es" hreflang="es-es" rel="alternate" target=""><p class="ProductCard-Info-Line1-Title">HYACINTH</p><div class="ProductCard-Info-Line1-Price"><label>124,90 €</label></div></a><div class="ProductCard-Info-Line2"><p class="ProductCard-Info-Line2-Brand"></p><div class="ProductCard-Info-Colors"><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#0022ff"></div></div><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#ff0080"></div></div><div class="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0 dVXinZ ProductVariantsItem"><style data-emotion="css 1ixbp0l">.css-1ixbp0l{pointer-events:none;}</style><div class="ProductVariantsItem-Item" style="background-color:#32cd32"></div></div></div></div></div></div><div class="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 kDLTuk ProductCard"><div class="ProductCard-Header"><div class="ProductCard-Header-Fav"></div></div><a class="ProductCard-Image center cover" href="/es/rohe-mng5628-es" hreflang="es-es" rel="alternate" target=""><img alt="ROHE NEGRO" class="imgCover" loading="lazy" src="https://d2wzbrvl8utv4v.cloudfront.net/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/m/n/mng562810.png"/></a><div class="ProductCard-Info"><a class="ProductCard-Info-Line1" href="/es/rohe-mng5628-es" hreflang="es-es" rel="alternate" target=""><p class="ProductCard-Info-Line1-Title">ROHE</p><div class="ProductCard-Info-Line1-Price"><label>104,90 €</label></div></a><div class="ProductCard-Info-Line2"><p class="ProductCard-Info-Line2-Brand"></p><div class="ProductCard-Info-Colors"><div class="ProductVaria ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="es_ES"><head><meta charset="utf-8"/><title>Gafas graduadas l Opticalia</title><meta content="La mayor selección de gafas graduadas en Opticalia. Encuentra las mejores marcas y modelos de gafas, perfectas para tu rostro y tu mirada." name="description"/><link href="" rel="apple-touch-icon" sizes="180x180"/><link href="" rel="icon" sizes="32x32" type="image/png"/><link href="" rel="icon" sizes="16x16" type="image/png"/><link href="/site.webmanifest" rel="manifest"/><link color="#000000" href="/safari-pinned-tab.svg" rel="mask-icon"/><meta content="#000000" name="msapplication-TileColor"/><meta content="#000000" name="theme-color"/><meta content="initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="Gafas graduadas l Opticalia" name="og:title" property="og:title"/><meta content="La mayor selección de gafas graduadas en Opticalia. Encuentra las mejores marcas y modelos de gafas, perfectas para tu rostro y tu mirada." name="og:description" property="og:description"/><meta content="Opticalia" property="og:site_name"/><meta content="https://www.opticalia.com/es/graduadas" property="og:url"/><meta content="summary" name="twitter:card"/><meta content="Gafas graduadas l Opticalia" name="twitter:title"/><meta content="La mayor selección de gafas graduadas en Opticalia. Encuentra las mejores marcas y modelos de gafas, perfectas para tu rostro y tu mirada." name="twitter:description"/><meta content="" name="google-site-verification"/><meta content="" name="facebook-domain-verification"/><link href="https://www.opticalia.com/es/graduadas" rel="canonical"/><script async="" id="CookieDeclaration" src="https://consent.cookiebot.com/36d20743-d8cd-4090-a0bc-8414406309b5/cd.js" type="text/javascript"></script><link as="font" crossorigin="" href="/static/fonts/ITCGaramondStd-LtCondIta.otf" rel="preload" type="font/otf"/><link as="font" crossorigin="" href="/static/fonts/ITCGaramondStd-LtCond.otf" rel="preload" type="font/otf"/><meta content="24" name="next-head-count"/><link as="style" href="/_next/static/css/95df004ac2557175daa3.css" rel="preload"/><link data-n-g="" href="/_next/static/css/95df004ac2557175daa3.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-e7a279300235e161e32a.js"></script><script defer="" src="/_next/static/chunks/webpack-1db7e1524d5269f86240.js"></script><script defer="" src="/_next/static/chunks/framework-d9cd8c00a7d7c8d8c129.js"></script><script defer="" src="/_next/static/chunks/main-e5f07ede970874fa4e5d.js"></script><script defer="" src="/_next/static/chunks/pages/_app-2ee64fd38cb0582755b1.js"></script><script defer="" src="/_next/static/chunks/pages/%5Bstore%5D/%5B...slug%5D-71c89b4d157842aeb57f.js"></script><script defer="" src="/_next/static/b6QbmkzGzb7ic15HfTuv0/_buildManifest.js"></script><script defer="" src="/_next/static/b6QbmkzGzb7ic15HfTuv0/_ssgManifest.js"></script><style id="__jsx-625733788">#nprogress{pointer-events:none;}#nprogress .bar{background:#0084FF;position:fixed;z-index:9999;top:0;left:0;width:100%;height:7px;}#nprogress .peg{display:block;position:absolute;right:0px;width:100px;height:100%;box-shadow:0 0 10px #0084FF,0 0 5px #0084FF;opacity:1;-webkit-transform:rotate(3deg) translate(0px,-4px);-ms-transform:rotate(3deg) translate(0px,-4px);-webkit-transform:rotate(3deg) translate(0px,-4px);-ms-transform:rotate(3deg) translate(0px,-4px);transform:rotate(3deg) translate(0px,-4px);}#nprogress .spinner{display:block;position:fixed;z-index:1031;top:15px;right:15px;}#nprogress .spinner-icon{width:18px;height:18px;box-sizing:border-box;border:solid 2px transparent;border-top-color:#0084FF;border-left-color:#0084FF;border-radius:50%;-webkit-animation:nprogresss-spinner 400ms linear infinite;-webkit-animation:nprogress-spinner 400ms linear infinite;animation:nprogress-spinner 400ms linear infinite;}.nprogress-custom-parent{overflow:hidden;position:relative;}.nprogress-custom-parent #nprogress .s ...
# .fdaqpI:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .fdaqpI:disabled{background-color:#999999 !important;cursor:default !important;}/*!sc*/
# .fdaqpI.Button-Seconday{background-color:transparent;border:1px solid black;color:black;}/*!sc*/
# @media screen and (max-width:768px){.fdaqpI{margin:0.4rem 0;min-width:6.25rem;}}/*!sc*/
# .fdaqpI img{margin-right:0.4rem;width:100%;}/*!sc*/
# .gPOaQP{min-width:10.7rem;height:2.4rem;background-color:black;color:#FCFBFA;text-transform:uppercase;-webkit-text-decoration:underline;text-decoration:underline;border-style:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0;cursor:pointer;font-size:0.8rem;-webkit-transition:all ease 250ms;transition:all ease 250ms;background-color:white;color:black;border-color:black;border-style:solid;border-width:1px;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gPOaQP:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .gPOaQP:disabled{background-color:#999999 !important;cursor:default !important;}/*!sc*/
# .gPOaQP.Button-Seconday{background-color:transparent;border:1px solid black;color:black;}/*!sc*/
# @media screen and (max-width:768px){.gPOaQP{margin:0.4rem 0;min-width:6.25rem;}}/*!sc*/
# .gPOaQP:disabled{background-color:white !important;cursor:default !important;color:#999999;border-color:#999999;}/*!sc*/
# .gPOaQP img{margin-right:0.4rem;width:100%;}/*!sc*/
# data-styled.g2[id="Buttonstyled__ButtonStyles-sc-16hwl9t-0"]{content:"fdaqpI,gPOaQP,"}/*!sc*/
# .npSkv{position:fixed;left:0;top:0;z-index:9999;background-color:rgba(200,200,200,0.6);width:100%;height:100%;display:none;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .npSkv .Loading-Window{background-color:transparent;width:340px;height:200px;-webkit-animation-duration:300ms;animation-duration:300ms;}/*!sc*/
# data-styled.g3[id="loadingcontext__LoadingStyles-sc-14qtxzv-0"]{content:"npSkv,"}/*!sc*/
# .SCEMj{height:1.6rem;width:100%;-webkit-transition:all ease 300ms;transition:all ease 300ms;}/*!sc*/
# .SCEMj .BannerLine-Banner{overflow:hidden;}/*!sc*/
# .SCEMj .BannerLine-Banner a p{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .SCEMj .BannerLine-Content{padding:0 1.5rem;font-size:0.7rem;}/*!sc*/
# .SCEMj .BannerLine-Content p{color:white;margin:0;overflow:hidden;white-space:nowrap;}/*!sc*/
# .SCEMj .BannerLine-Content u{-webkit-text-decoration:none;text-decoration:none;margin:0.75rem;}/*!sc*/
# .SCEMj.BannerLine-Scroll .BannerLine-Content{-webkit-animation:scrollText 25s infinite linear;animation:scrollText 25s infinite linear;}/*!sc*/
# .SCEMj.BannerLine-Scroll .BannerLine-Banner{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# .SCEMj.BannerLine-header{background-color:black;}/*!sc*/
# .SCEMj.BannerLine-footer{background-color:#0084FF;}/*!sc*/
# @-webkit-keyframes scrollText{from{-webkit-transform:translateX(0%);-ms-transform:translateX(0%);transform:translateX(0%);}to{-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);}}/*!sc*/
# @keyframes scrollText{from{-webkit-transform:translateX(0%);-ms-transform:translateX(0%);transform:translateX(0%);}to{-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);}}/*!sc*/
# data-styled.g5[id="BannerLinestyled__BannerLineStyles-sc-fw8o68-0"]{content:"SCEMj,"}/*!sc*/
# .jkHKyL{position:absolute;top:1.6rem;right:1.6rem;width:1.6rem;height:1.6rem;-webkit-transition:all ease 250ms;transition:all ease 250ms;cursor:pointer;}/*!sc*/
# .jkHKyL:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# @media screen and (max-width:768px){.jkHKyL{top:0.8rem;right:0.8rem;}}/*!sc*/
# data-styled.g6[id="CloseModalBtn__CloseModalStyles-sc-1n8w2jo-0"]{content:"jkHKyL,"}/*!sc*/
# .jIjHRt{position:fixed;right:0;top:0;height:100%;z-index:100;background-color:rgba(12,12,12,0.5);-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;display:none;overflow:hidden;}/*!sc*/
# .jIjHRt .Cart-Content{width:30.65rem;height:100%;background-color:white;position:relative;display:grid;grid-template-rows:max-content auto max-content;-webkit-animation-duration:250ms;animation-duration:250ms;}/*!sc*/
# .jIjHRt .Cart-Header{padding:1.7rem 0.8rem;}/*!sc*/
# .jIjHRt .Cart-BagTitle{margin:0;font-size:1.2rem;}/*!sc*/
# .jIjHRt .Cart-Items{overflow-y:auto;padding:0 0.8rem;padding-right:2rem;}/*!sc*/
# .jIjHRt .Cart-Footer{padding:0.8rem;}/*!sc*/
# .jIjHRt .Cart-Footer-FinishBtn{width:100%;}/*!sc*/
# .jIjHRt .Cart-Footer-Discounts{border-bottom-style:solid;border-width:1px;border-color:black;font-size:0.8rem;}/*!sc*/
# .jIjHRt .Cart-Footer-Discounts-Title{font-size:1.2rem;margin:0;}/*!sc*/
# .jIjHRt .Cart-Footer-Discounts-Item{display:grid;grid-template-columns:min-content auto max-content;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .jIjHRt .Cart-Footer-Discounts-Item span{padding-right:1.25rem;}/*!sc*/
# .jIjHRt .Cart-Footer-Discounts-Item p{max-width:17.5rem;}/*!sc*/
# .jIjHRt .Cart-Footer-Shipping{height:2.6rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-size:0.8rem;border-bottom-style:solid;border-width:1px;border-color:black;}/*!sc*/
# .jIjHRt .Cart-Footer-Shipping p{margin:0;}/*!sc*/
# .jIjHRt .Cart-Footer-Shipping label{color:#828283;}/*!sc*/
# .jIjHRt .Cart-Footer-Total{height:3rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .jIjHRt .Cart-Footer-Total p,.jIjHRt .Cart-Footer-Total label{font-size:1.2rem;margin:0;}/*!sc*/
# .jIjHRt .Cart-Footer-Total p span,.jIjHRt .Cart-Footer-Total label span{font-size:0.6rem;color:#828283;}/*!sc*/
# .jIjHRt .Cart-Footer-Conditions{font-size:0.5rem;display:block;margin:0;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;opacity:0.6;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g8[id="Cartstyled__CartStyles-sc-xo8wsa-0"]{content:"jIjHRt,"}/*!sc*/
# .bFliQo{position:relative;padding-bottom:0.8rem;grid-template-columns:auto max-content;}/*!sc*/
# .bFliQo input{width:100%;height:100%;font-size:0.8rem;color:#828283;padding:0 0.8rem;border-style:none;}/*!sc*/
# .bFliQo label{font-size:0.6rem;line-height:0.8rem;}/*!sc*/
# .bFliQo .CustomInput-Wrap{height:2.4rem;border-style:solid;border-color:#999999;border-width:1px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .bFliQo button{border-radius:none;border-style:none;background:transparent;color:#828283;text-transform:uppercase;-webkit-text-decoration:underline;text-decoration:underline;font-weight:500;cursor:pointer;padding-right:0.8rem;font-size:0.8rem;}/*!sc*/
# .isIiij{position:relative;padding-bottom:0.8rem;grid-template-columns:auto max-content;}/*!sc*/
# .isIiij input{width:100%;height:100%;font-size:0.8rem;color:#828283;padding:0 0.8rem;border-style:none;}/*!sc*/
# .isIiij label{font-size:0.6rem;line-height:0.8rem;}/*!sc*/
# .isIiij .CustomInput-Wrap{height:2.4rem;border-style:solid;border-color:#999999;border-width:1px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;border-style:none;border-bottom-style:solid;}/*!sc*/
# .isIiij button{border-radius:none;border-style:none;background:transparent;color:#828283;text-transform:uppercase;-webkit-text-decoration:underline;text-decoration:underline;font-weight:500;cursor:pointer;padding-right:0.8rem;font-size:0.8rem;}/*!sc*/
# data-styled.g10[id="CustomInputstyled__CustomInputStyles-sc-13vc4l-0"]{content:"bFliQo,isIiij,"}/*!sc*/
# .inxQJr{position:relative;padding-bottom:0.8rem;}/*!sc*/
# .inxQJr .MuiInputBase-root{height:100%;}/*!sc*/
# .inxQJr .MuiInputBase-root select{height:100%;}/*!sc*/
# .inxQJr .MuiInputBase-root{padding-right:1rem;}/*!sc*/
# .inxQJr fieldset{border-style:none;}/*!sc*/
# .inxQJr .MuiOutlinedInput-root{width:100%;}/*!sc*/
# .inxQJr .MuiSelect-select{font-size:0.8rem;min-height:unset;height:100%;padding:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-left:0.45rem;}/*!sc*/
# .inxQJr .CustomSelect-Placeholder{color:#828283;}/*!sc*/
# .inxQJr .CustomSelect-Wrap{height:2.4rem;border-style:solid;border-color:#999999;border-width:1px;}/*!sc*/
# .inxQJr .CustomSelect-Label{font-size:0.6rem;line-height:0.8rem;}/*!sc*/
# data-styled.g11[id="CustomSelectstyled__CustomSelectStyles-sc-121m7uf-0"]{content:"inxQJr,"}/*!sc*/
# .bWZPRw{margin-top:0.8rem;}/*!sc*/
# data-styled.g22[id="CoupunInputstyled__CoupunInputStyles-sc-14xtjmc-0"]{content:"bWZPRw,"}/*!sc*/
# .bqsKgs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-transition:all ease 250ms;transition:all ease 250ms;cursor:pointer;}/*!sc*/
# .bqsKgs:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# data-styled.g25[id="Iconstyled__IconStyles-sc-199mfc0-0"]{content:"bqsKgs,"}/*!sc*/
# .ibuIrn{min-height:10rem;width:100%;background-color:black;margin-top:1rem;}/*!sc*/
# .ibuIrn .Footer-Wrap{padding:0 2rem;padding-top:6.4rem;max-width:1440px;margin:auto;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Wrap{padding:0 1.2rem;padding-top:2.4rem;}}/*!sc*/
# .ibuIrn .Footer-Content{padding-bottom:4rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:4rem;border-bottom-style:solid;border-color:#FFFDFB;border-width:1px;position:relative;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Content{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# .ibuIrn .Footer-Content p{color:white;}/*!sc*/
# .ibuIrn .Footer-Content-Socials{position:absolute;right:0;bottom:1.6rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:0.8rem;}/*!sc*/
# .ibuIrn .Footer-Row-Title{margin:0;margin-bottom:2rem;font-size:0.7rem;}/*!sc*/
# .ibuIrn .Footer-Row-Item{margin:0;font-size:0.8rem;line-height:1.5rem;-webkit-letter-spacing:-0.005em;-moz-letter-spacing:-0.005em;-ms-letter-spacing:-0.005em;letter-spacing:-0.005em;}/*!sc*/
# .ibuIrn .Footer-Card{width:2.1rem;height:1.25rem;overflow:hidden;border-radius:4px;}/*!sc*/
# .ibuIrn .Footer-Card img{width:100%;}/*!sc*/
# .ibuIrn .Footer-Bottom{height:7.85rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;gap:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Bottom{height:-webkit-fit-content;height:-moz-fit-content;height:fit-content;padding-bottom:2rem;}}/*!sc*/
# .ibuIrn .Footer-Bottom-Row{width:100%;display:grid;grid-template-columns:auto max-content;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Bottom-Row{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Links{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:1.6rem;}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Links a{color:white;font-size:0.6rem;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Bottom-Row-Links{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;gap:0.6rem;padding-top:1.5rem;}.ibuIrn .Footer-Bottom-Row-Links a{text-align:center;}}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Cards{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:1.1rem;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Bottom-Row-Cards{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:12.5rem;margin-top:2rem;padding-bottom:1.5rem;}}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Establishment{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Establishment p{font-size:0.8rem;color:white;}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Establishment img{width:1.8rem;margin-left:0.8rem;}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Help{position:fixed;bottom:0.5rem;right:7.5rem;background-color:black;z-index:2147483646;border-radius:15rem;width:2.5rem;height:2.5rem;cursor:pointer;}/*!sc*/
# @media screen and (max-width:768px){.ibuIrn .Footer-Bottom-Row-Help{right:0.5rem;}}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Help img{width:1.6rem;}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Help div{margin-left:2.6rem;}/*!sc*/
# .ibuIrn .Footer-Bottom-Row-Help div p{font-size:0.8rem;color:white;margin:0;margin-left:0.7rem;}/*!sc*/
# .ibuIrn .Footer-StoreSelect{margin-top:2.3rem;width:16.4rem;}/*!sc*/
# .ibuIrn .Footer-StoreSelect p{font-size:0.8rem;margin-bottom:0.4rem;}/*!sc*/
# data-styled.g26[id="Footerstyled__FooterStyles-sc-lybkub-0"]{content:"ibuIrn,"}/*!sc*/
# .kbiokz{position:fixed;width:100%;height:100%;padding-top:3.2rem;top:0;z-index:-1;display:none;-webkit-animation-duration:300ms;animation-duration:300ms;}/*!sc*/
# @media screen and (max-width:768px){.kbiokz{display:none;}}/*!sc*/
# .kbiokz .MobileMenu-Content{background-color:white;border-top-style:solid;border-width:1px;border-color:#D9D9D9;padding:0 0.8rem;padding-top:2.5rem;display:grid;grid-template-rows:max-content auto max-content;grid-template-columns:100%;}/*!sc*/
# .kbiokz .MobileMenu-Categories{border-bottom-style:solid;border-width:1px;border-color:#B4B4B6;padding-bottom:1rem;overflow-y:auto;}/*!sc*/
# .kbiokz .MobileMenu-Categories-Item label{font-size:0.6rem;color:#999999;margin-bottom:0.5rem;display:block;margin-top:1.3rem;}/*!sc*/
# @media screen and (max-width:768px){.kbiokz .MobileMenu-Categories-Item label:nth-child(1){margin-top:0;}}/*!sc*/
# .kbiokz .MobileMenu-Categories-Item-Title{font-size:1.2rem;margin:0;border-width:1px;border-color:#0092BC;}/*!sc*/
# .kbiokz .MobileMenu-Categories-Item-Subtitle{font-size:0.8rem;margin:0;margin-bottom:0.4rem;}/*!sc*/
# .kbiokz .MobileMenu-Categories-Footer{margin-top:1.2rem;padding-bottom:0.5rem;border-top-style:solid;border-bottom-style:solid;border-width:1px;border-color:#B4B4B6;}/*!sc*/
# .kbiokz .MuiAccordionSummary-root,.kbiokz .MuiAccordion-root{box-shadow:none;padding:0;}/*!sc*/
# data-styled.g30[id="MobileMenustyled__MobileMenuStyles-sc-1l88xl9-0"]{content:"kbiokz,"}/*!sc*/
# .gGLUdo{color:#000;}/*!sc*/
# data-styled.g32[id="ColorTextstyled__ColorText-sc-1aohq2r-0"]{content:"gGLUdo,"}/*!sc*/
# .fHjova{width:100%;background-color:white;position:fixed;top:0;left:0;z-index:99;overflow:hidden;-webkit-transition:all ease 400ms;transition:all ease 400ms;box-shadow:0px 2px 4px rgba(0,0,0,0.15);}/*!sc*/
# .fHjova .MainHeader-MobileMenu{display:none;height:100%;width:2rem;padding-left:0.4rem;}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-MobileMenu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;cursor:pointer;-webkit-transition:all ease 250ms;transition:all ease 250ms;}.fHjova .MainHeader-MobileMenu:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-SearchIcon{display:none;}}/*!sc*/
# .fHjova .MainHeader-Logo{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .fHjova .MainHeader-Logo img{width:6rem;}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-Logo img{width:4.5rem;}}/*!sc*/
# .fHjova .MainHeader-Wrap{display:grid;grid-template-columns:45% 10% 45%;background-color:white;position:relative;height:3.2rem;max-width:1360px;margin:auto;}/*!sc*/
# .fHjova .MainHeader-Categories{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;font-size:0.8rem;}/*!sc*/
# @media (min-width:1360px){.fHjova .MainHeader-Categories{margin-left:-0.8rem;}}/*!sc*/
# @media (max-width:1360px){.fHjova .MainHeader-Categories{padding-left:1.2rem;}}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-Categories{display:none;}}/*!sc*/
# .fHjova .MainHeader-Categories-Wrap{height:110%;}/*!sc*/
# .fHjova .MainHeader-Categories-Item{padding:0 0.8rem;position:relative;margin:0;}/*!sc*/
# .fHjova .MainHeader-Categories-Item::before{content:"";width:40%;height:4px;background-color:#0084FF;position:absolute;bottom:0.15rem;border-radius:20px;opacity:0;-webkit-transition:all ease 200ms;transition:all ease 200ms;}/*!sc*/
# .fHjova .MainHeader-Categories-Item.Active::before{opacity:1;width:100%;}/*!sc*/
# .fHjova .MainHeader-SubCategories{position:fixed;width:100%;left:0;background-color:white;height:27rem;top:3.2rem;-webkit-transition:all ease 200ms;transition:all ease 200ms;z-index:-7;display:none;}/*!sc*/
# .fHjova .MainHeader-SubCategories.Active{display:block;}/*!sc*/
# .fHjova .MainHeader-SubCategories.Active .HeaderMenu-Wrap{-webkit-animation-name:showSubCategorie;animation-name:showSubCategorie;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation-timing-function:ease;animation-timing-function:ease;-webkit-animation-duration:200ms;animation-duration:200ms;}/*!sc*/
# .fHjova .MainHeader-Right{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;font-size:0.8rem;padding-left:4.5rem;}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-Right-Links{display:none;}}/*!sc*/
# .fHjova .MainHeader-Right-Links a{padding:0 0.8rem;position:relative;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .fHjova .MainHeader-Right-Links a p{margin:0;}/*!sc*/
# .fHjova .MainHeader-Right-Links a::before{content:"";width:40%;height:4px;background-color:#0084FF;position:absolute;bottom:0rem;border-radius:20px;opacity:0;-webkit-transition:all ease 200ms;transition:all ease 200ms;}/*!sc*/
# .fHjova .MainHeader-Right-Links a:hover::before{opacity:1;width:100%;}/*!sc*/
# .fHjova .MainHeader-Right-Icons{gap:0.8rem;margin-left:1.5rem;}/*!sc*/
# @media (max-width:1360px){.fHjova .MainHeader-Right-Icons{margin-right:0.8rem;}}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-Right-Icons{margin-right:0;}}/*!sc*/
# .fHjova .MainHeader-Right-Icons img{width:1.6rem;height:1.6rem;cursor:pointer;}/*!sc*/
# .fHjova .MainHeader-Right-Icons button{height:1.6rem;font-size:0.6rem;min-width:unset;width:5rem;}/*!sc*/
# .fHjova .MainHeader-RequestAppointment{padding:0;}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-RequestAppointment{display:none;}}/*!sc*/
# .fHjova .MainHeader-RequestAppointment-Mobile{display:none;}/*!sc*/
# @media screen and (max-width:768px){.fHjova .MainHeader-RequestAppointment-Mobile{display:block;min-width:6.5rem;margin-top:1.5rem;}}/*!sc*/
# .fHjova .MainHeader-SearchContent{box-shadow:0px 2px 4px rgb(0 0 0 / 5%);padding:2rem;}/*!sc*/
# .fHjova .MainHeader-SearchContent-Title p{font-size:3.6rem;line-height:3.4rem;font-family:'ITC-Cond',sans-serif;margin:0;max-width:33.35rem;}/*!sc*/
# .fHjova .MainHeader-SearchContent .CustomInput{max-width:33.35rem;margin-top:4.4rem;}/*!sc*/
# @media screen and (max-width:768px){.fHjova .LocaleSelect{display:none;}}/*!sc*/
# @-webkit-keyframes showSubCategorie{from{-webkit-transform:translateY(-5rem);-ms-transform:translateY(-5rem);transform:translateY(-5rem);}to{-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);}}/*!sc*/
# @keyframes showSubCategorie{from{-webkit-transform:translateY(-5rem);-ms-transform:translateY(-5rem);transform:translateY(-5rem);}to{-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);}}/*!sc*/
# data-styled.g33[id="Headerstyled__HeaderStyles-sc-13wp04m-0"]{content:"fHjova,"}/*!sc*/
# .gBIGbE .BannerGridCms-Content{display:grid;grid-template-rows:auto;}/*!sc*/
# .gBIGbE .BannerGridCms-Image{max-height:43rem;overflow:hidden;}/*!sc*/
# .gBIGbE .BannerGridCms-Image img{-webkit-transition:all ease 400ms;transition:all ease 400ms;}/*!sc*/
# @media screen and (max-width:768px){}/*!sc*/
# .gBIGbE .BannerGridCms-Description{margin:0;font-size:0.8rem;line-height:1rem;margin-top:0.8rem;}/*!sc*/
# data-styled.g34[id="BannerGridstyled__BannerGridCmsStyles-sc-1rgy4sj-0"]{content:"gBIGbE,"}/*!sc*/
# .eLSMdV .ServiceGridCms-Content{position:relative;}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Title{-webkit-hyphens:auto;-moz-hyphens:auto;-ms-hyphens:auto;hyphens:auto;word-wrap:break-word;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Title p{font-size:2.7rem;font-family:'ITC-Cond',sans-serif;margin:0;line-height:2.5rem;}/*!sc*/
# .eLSMdV .ServiceGridCms-Title p em{font-family:'ITC-Italic',sans-serif;}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Title p{font-size:2.8rem;line-height:2.6rem;}}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Title p{font-size:2.8rem;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Wrap{padding:2rem;position:absolute;left:0;top:0;}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Wrap{padding:1.2rem;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Background{position:absolute;left:0;top:0;}/*!sc*/
# .eLSMdV .ServiceGridCms-Footer{position:absolute;bottom:0;left:0;padding:2rem;padding-top:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;width:100%;}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Footer{padding:1.2rem;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Description{max-width:20.15rem;}/*!sc*/
# .eLSMdV .ServiceGridCms-Description p{font-size:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Description p{font-size:0.8rem;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Buttons{margin-top:0.8rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Buttons button{margin:0.4rem 0;min-width:7rem;font-size:0.6rem;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Button{min-width:10.7rem;height:2.4rem;background-color:black;color:white;text-transform:uppercase;-webkit-text-decoration:underline;text-decoration:underline;border-style:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;-webkit-transition:all ease 250ms;transition:all ease 250ms;}/*!sc*/
# .eLSMdV .ServiceGridCms-Button:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# @media screen and (max-width:768px){.eLSMdV .ServiceGridCms-Button{margin:0.4rem 0;}}/*!sc*/
# .eLSMdV .ServiceGridCms-Link{font-size:0.8rem;font-weight:500;}/*!sc*/
# .eLSMdV .ServiceGridCms-Link a{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g35[id="ServiceGridstyled__ServiceGridCmsStyles-sc-1649rrb-0"]{content:"eLSMdV,"}/*!sc*/
# .bbtkJA{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:1.5rem 0;}/*!sc*/
# @media (max-width:1440px){.bbtkJA{width:100%;margin-left:unset;}}/*!sc*/
# @media (min-width:1360px){.bbtkJA{width:calc(100% + 0.8rem);margin-left:-0.4rem;}}/*!sc*/
# .bbtkJA .MainGrid-Content{width:100%;}/*!sc*/
# @media screen and (max-width:768px){}/*!sc*/
# .bbtkJA .MainGrid-Item{padding:0.4rem;float:right;}/*!sc*/
# .bbtkJA .MainGrid-Item._1x1{height:23.5rem;width:33.333333333333336%;}/*!sc*/
# @media screen and (max-width:768px){.bbtkJA .MainGrid-Item._1x1{width:50%;height:17.5rem;}}/*!sc*/
# .bbtkJA .MainGrid-Item._2x2{height:47rem;width:66.66666666666667%;}/*!sc*/
# @media screen and (max-width:768px){.bbtkJA .MainGrid-Item._2x2{width:100%;height:auto;}}/*!sc*/
# .bbtkJA .MainGrid-Item._2x1{height:23.5rem;width:66.66666666666667%;}/*!sc*/
# @media screen and (max-width:768px){.bbtkJA .MainGrid-Item._2x1{width:100%;height:20rem;}}/*!sc*/
# .bbtkJA .MainGrid-Item._3x1{height:23.5rem;width:100%;height:20rem;}/*!sc*/
# .ecZavg{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:1.5rem 0;}/*!sc*/
# @media (max-width:1440px){.ecZavg{width:100%;margin-left:unset;}}/*!sc*/
# @media (min-width:1360px){.ecZavg{width:calc(100% + 0.8rem);margin-left:-0.4rem;}}/*!sc*/
# .ecZavg .MainGrid-Content{width:100%;}/*!sc*/
# @media screen and (max-width:768px){}/*!sc*/
# .ecZavg .MainGrid-Item{padding:0.4rem;float:right;}/*!sc*/
# .ecZavg .MainGrid-Item._1x1{height:30rem;width:33.333333333333336%;}/*!sc*/
# @media screen and (max-width:768px){.ecZavg .MainGrid-Item._1x1{width:50%;height:17.5rem;}}/*!sc*/
# .ecZavg .MainGrid-Item._2x2{height:60rem;width:66.66666666666667%;}/*!sc*/
# @media screen and (max-width:768px){.ecZavg .MainGrid-Item._2x2{width:100%;height:auto;}}/*!sc*/
# .ecZavg .MainGrid-Item._2x1{height:30rem;width:66.66666666666667%;}/*!sc*/
# @media screen and (max-width:768px){.ecZavg .MainGrid-Item._2x1{width:100%;height:20rem;}}/*!sc*/
# .ecZavg .MainGrid-Item._3x1{height:30rem;width:100%;height:20rem;}/*!sc*/
# .lfWcXp{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:1.5rem 0;}/*!sc*/
# @media (max-width:1440px){.lfWcXp{width:100%;margin-left:unset;}}/*!sc*/
# @media (min-width:1360px){.lfWcXp{width:calc(100% + 0.8rem);margin-left:-0.4rem;}}/*!sc*/
# .lfWcXp .MainGrid-Content{width:100%;}/*!sc*/
# @media screen and (max-width:768px){.lfWcXp .MainGrid-Content{display:grid;grid-template-columns:repeat(2,14.15rem);overflow-x:auto;padding-bottom:1rem;}}/*!sc*/
# .lfWcXp .MainGrid-Item{padding:0.4rem;float:left;}/*!sc*/
# .lfWcXp .MainGrid-Item._1x1{height:25rem;width:33.333333333333336%;}/*!sc*/
# @media screen and (max-width:768px){.lfWcXp .MainGrid-Item._1x1{width:50%;height:17.5rem;}@media screen and (max-width:768px){.lfWcXp .MainGrid-Item._1x1{width:100%;}}}/*!sc*/
# .lfWcXp .MainGrid-Item._2x2{height:50rem;width:66.66666666666667%;}/*!sc*/
# @media screen and (max-width:768px){.lfWcXp .MainGrid-Item._2x2{width:100%;height:auto;}}/*!sc*/
# .lfWcXp .MainGrid-Item._2x1{height:25rem;width:66.66666666666667%;}/*!sc*/
# @media screen and (max-width:768px){.lfWcXp .MainGrid-Item._2x1{width:100%;height:20rem;}}/*!sc*/
# .lfWcXp .MainGrid-Item._3x1{height:25rem;width:100%;height:20rem;}/*!sc*/
# data-styled.g37[id="MainGridstyles__MainGridStyles-sc-1478f0s-0"]{content:"bbtkJA,ecZavg,lfWcXp,"}/*!sc*/
# .knZHyN{padding:2rem;box-shadow:0px 2px 4px rgba(0,0,0,0.15);border-top-style:solid;border-top-color:#D9D9D9;border-width:1px;}/*!sc*/
# .knZHyN a:hover p{color:#0084FF;}/*!sc*/
# .knZHyN .HeaderMenu-Wrap{display:grid;grid-template-columns:22rem auto;max-width:1440px;margin:auto;}/*!sc*/
# .knZHyN .HeaderMenu-Category{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}/*!sc*/
# .knZHyN .HeaderMenu-Category-Title{color:#828283;font-size:0.7rem;margin:0;margin-bottom:1.2rem;}/*!sc*/
# .knZHyN .HeaderMenu-Category-Item p{font-size:0.8rem;margin:0;margin-bottom:0.4rem;}/*!sc*/
# .knZHyN .HeaderMenu-Categories{position:relative;}/*!sc*/
# .knZHyN .HeaderMenu-Categories >:last-child::before{content:"";background-color:black;width:2rem;height:1px;position:absolute;left:0;bottom:-2rem;}/*!sc*/
# .knZHyN .HeaderMenu-Banners .MainGrid{padding:0;}/*!sc*/
# .knZHyN .HeaderMenu-Banners .MainGrid-Content{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# .knZHyN .HeaderMenu-Banners .MainGrid-Item._1x1{height:23.5rem;width:33.3%;}/*!sc*/
# .knZHyN .HeaderMenu-Banners .MainGrid-Item._2x2{height:23.5rem;width:66.6%;}/*!sc*/
# .knZHyN .HeaderMenu-Banners .MainGrid-Item._2x1{height:23.5rem;width:66.6%;}/*!sc*/
# .knZHyN .HeaderMenu-Banners .MainGrid .BannerGridCms:hover .BannerGridCms-Image img{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}/*!sc*/
# .knZHyN .HeaderMenu-Footer{padding-top:2rem;margin-top:2rem;position:relative;}/*!sc*/
# .knZHyN .HeaderMenu-Footer-Title{font-size:0.7rem;color:#828283;margin:0;margin-bottom:1.2rem;}/*!sc*/
# .knZHyN .HeaderMenu-Footer-Item{font-size:0.8rem;margin:0;margin-bottom:0.4rem;}/*!sc*/
# .bczYNm{padding:2rem;box-shadow:0px 2px 4px rgba(0,0,0,0.15);border-top-style:solid;border-top-color:#D9D9D9;border-width:1px;}/*!sc*/
# .bczYNm a:hover p{color:#0084FF;}/*!sc*/
# .bczYNm .HeaderMenu-Wrap{display:grid;grid-template-columns:22rem auto;max-width:1440px;margin:auto;}/*!sc*/
# .bczYNm .HeaderMenu-Category{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}/*!sc*/
# .bczYNm .HeaderMenu-Category-Title{color:#828283;font-size:0.7rem;margin:0;margin-bottom:1.2rem;}/*!sc*/
# .bczYNm .HeaderMenu-Category-Item p{font-size:0.8rem;margin:0;margin-bottom:0.4rem;}/*!sc*/
# .bczYNm .HeaderMenu-Categories{position:relative;}/*!sc*/
# .bczYNm .HeaderMenu-Categories >:last-child::before{content:"";background-color:black;width:2rem;height:1px;position:absolute;left:0;bottom:-2rem;}/*!sc*/
# .bczYNm .HeaderMenu-Banners .MainGrid{padding:0;}/*!sc*/
# .bczYNm .HeaderMenu-Banners .MainGrid-Content{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# .bczYNm .HeaderMenu-Banners .MainGrid-Item._1x1{height:23.5rem;width:33.3%;}/*!sc*/
# .bczYNm .HeaderMenu-Banners .MainGrid-Item._2x2{height:23.5rem;width:66.6%;}/*!sc*/
# .bczYNm .HeaderMenu-Banners .MainGrid-Item._2x1{height:23.5rem;width:66.6%;}/*!sc*/
# .bczYNm .HeaderMenu-Banners .MainGrid .BannerGridCms:hover .BannerGridCms-Image img{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}/*!sc*/
# .bczYNm .HeaderMenu-Footer{padding-top:2rem;margin-top:2rem;position:relative;}/*!sc*/
# .bczYNm .HeaderMenu-Footer-Title{font-size:0.7rem;color:#828283;margin:0;margin-bottom:1.2rem;}/*!sc*/
# .bczYNm .HeaderMenu-Footer-Item{font-size:0.8rem;margin:0;margin-bottom:0.4rem;}/*!sc*/
# data-styled.g38[id="HeaderMenustyled__HeaderMenuStyles-sc-1206ta2-0"]{content:"knZHyN,bczYNm,"}/*!sc*/
# .dVXinZ{width:2rem;height:2rem;}/*!sc*/
# .dVXinZ .ProductVariantsItem-Item{gap:0.5rem;border-style:solid;border-width:1px;border-color:black;text-transform:uppercase;background-color:white;display:inline-block;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;width:100%;height:100%;border-radius:50%;border:1px solid #D9D9D9;opacity:0.65;-webkit-transition:all ease 250ms;transition:all ease 250ms;}/*!sc*/
# .dVXinZ .ProductVariantsItem-Item:active{-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .dVXinZ .ProductVariantsItem-Item-Active{opacity:1;border:1px solid black;}/*!sc*/
# data-styled.g43[id="ProductVariantsItemstyled__ProductVariantsItemStyles-sc-1kc3qfp-0"]{content:"dVXinZ,"}/*!sc*/
# .kDLTuk{display:grid;grid-template-rows:auto max-content;position:relative;width:22.1rem;height:31.15rem;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk{width:8.2rem;height:16rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header{position:absolute;top:0;left:0;width:100%;padding:0.8rem 1rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:0.6rem;pointer-events:none;}/*!sc*/
# .kDLTuk .ProductCard-Header-Badge{border:1px solid black;border-radius:1.2rem;padding:0.35rem 0.6rem;background-color:#FBFBFB4D;pointer-events:all;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Header-Badge{line-height:0.6rem;padding:0.25rem 0.4rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header-Badge span{text-transform:uppercase;font-size:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Header-Badge span{font-size:0.4rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header-Badge-Red{border:1px solid red;border-radius:1.2rem;padding:0.35rem 0.6rem;background-color:red;pointer-events:all;color:#FFFFFF;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Header-Badge-Red{line-height:0.6rem;padding:0.25rem 0.4rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header-Badge-Red span{text-transform:uppercase;font-size:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Header-Badge-Red span{font-size:0.4rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header-Badge-Black{border:1px solid #000000;border-radius:1.2rem;padding:0.35rem 0.6rem;background-color:#000000;pointer-events:all;color:#FFFFFF;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Header-Badge-Black{line-height:0.6rem;padding:0.25rem 0.4rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header-Badge-Black span{text-transform:uppercase;font-size:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Header-Badge-Black span{font-size:0.4rem;}}/*!sc*/
# .kDLTuk .ProductCard-Header-Fav{width:1.2rem;height:1rem;cursor:pointer;pointer-events:all;}/*!sc*/
# .kDLTuk .ProductCard-Image{width:inherit;border:1px solid #E5E5E54D;overflow:hidden;background-color:#E5E5E54D;}/*!sc*/
# .kDLTuk .ProductCard-Info{width:inherit;padding-top:0.8rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Info{gap:0.8rem;}}/*!sc*/
# .kDLTuk .ProductCard-Info-Line1{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:0.4rem;}/*!sc*/
# .kDLTuk .ProductCard-Info-Line1-Title{min-width:0;-webkit-flex:1 1 100%;-ms-flex:1 1 100%;flex:1 1 100%;font-size:0.8rem;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;margin:0;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Info-Line1-Title{max-width:5.85rem;}}/*!sc*/
# .kDLTuk .ProductCard-Info-Line1-Price{-webkit-flex:0 0 max-content;-ms-flex:0 0 max-content;flex:0 0 max-content;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:0.8rem;}/*!sc*/
# .kDLTuk .ProductCard-Info-Line1-Price label{padding-left:0.75rem;}/*!sc*/
# .kDLTuk .ProductCard-Info-Line1-Price--Previous{-webkit-text-decoration:line-through;text-decoration:line-through;}/*!sc*/
# .kDLTuk .ProductCard-Info-Line1-Price--Promotion{color:#EC4A4A;}/*!sc*/
# .kDLTuk .ProductCard-Info-Line2{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:end;-webkit-box-align:end;-ms-flex-align:end;align-items:end;height:1.2rem;}/*!sc*/
# .kDLTuk .ProductCard-Info-Line2 p{font-size:0.7rem;line-height:0.7rem;color:#828283;margin:0;}/*!sc*/
# @media screen and (max-width:768px){.kDLTuk .ProductCard-Info-Line2{-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}}/*!sc*/
# .kDLTuk .ProductCard-Info-Colors{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:0.3rem;}/*!sc*/
# .kDLTuk .ProductVariantsItem{width:0.9rem;height:0.9rem;}/*!sc*/
# data-styled.g44[id="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0"]{content:"kDLTuk,"}/*!sc*/
# .bUZDTm{width:100%;padding-top:3rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:relative;}/*!sc*/
# @media screen and (max-width:768px){.bUZDTm{padding-top:3rem;}}/*!sc*/
# .bUZDTm .ProdcutsGrid-Content{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;row-gap:4.8rem;-webkit-column-gap:0.8rem;column-gap:0.8rem;margin-bottom:4.8rem;}/*!sc*/
# @media screen and (max-width:768px){.bUZDTm .ProdcutsGrid-Content{row-gap:2.4rem;display:grid;grid-template-columns:50% 50%;padding-right:0.8rem;}}/*!sc*/
# .bUZDTm .ProdcutsGrid-Buttons{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;gap:0.8rem;margin-bottom:2rem;}/*!sc*/
# .bUZDTm .ProdcutsGrid-Buttons button{padding:0 1.5rem;}/*!sc*/
# .bUZDTm .ProdcutsGrid-Links{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;gap:0.8rem;margin-bottom:6.4rem;}/*!sc*/
# .bUZDTm .ProdcutsGrid-Links a > span{font-size:0.8rem;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:768px){.bUZDTm .ProductCard{width:100%;}}/*!sc*/
# data-styled.g45[id="ProductsGridstyled__ProductsGridStyled-sc-10ok271-0"]{content:"bUZDTm,"}/*!sc*/
# @media screen and (min-width:768px){.cACmWR .ProductCard:nth-of-type(8n+4){width:33.6rem !important;height:46rem !important;margin:0 auto !important;}.cACmWR .ProductCard:nth-of-type(8n+4) .ProductCard{height:100%;width:100%;}.cACmWR .ProductCard:nth-of-type(8n+5){margin-left:22.9rem !important;}.cACmWR .ProductCard:nth-of-type(8n){margin-right:22.9rem !important;}}/*!sc*/
# data-styled.g46[id="ProductsGridstyled__ProductsGridLargeStyled-sc-10ok271-1"]{content:"cACmWR,"}/*!sc*/
# .bJzgFm{width:100%;background-color:white;position:absolute;top:0;left:0;z-index:10;overflow:hidden;box-shadow:0px 1px 0px rgba(0,0,0,0.15);}/*!sc*/
# .bJzgFm.fixed{position:fixed !important;top:3.2rem;padding:0 2rem;}/*!sc*/
# .bJzgFm .FiltersHeader-Wrap{padding:0.75rem 0 !important;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:100%;}/*!sc*/
# .bJzgFm .FiltersHeader-Wrap::after{content:"";background:black;position:absolute;top:0;left:0;width:100%;height:1px;}/*!sc*/
# .bJzgFm .FiltersHeader-Custom-Right-Views{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media screen and (max-width:768px){.bJzgFm .FiltersHeader-Custom-Right-Views{display:none;}}/*!sc*/
# .bJzgFm .FiltersHeader-Options{width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-right:0.6rem;font-size:0.8rem;}/*!sc*/
# @media screen and (max-width:768px){.bJzgFm .FiltersHeader-Options{width:100%;}}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Wrap{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:100%;}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Item{padding:0 0.8rem;position:relative;margin:0;}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Item::before{content:"";width:40%;height:4px;background-color:#0084FF;position:absolute;bottom:0.15rem;border-radius:20px;opacity:0;-webkit-transition:all ease 200ms;transition:all ease 200ms;}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Item.Active::before{opacity:1;width:100%;}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Span{z-index:9;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Span .chevron{-moz-transition:all 0.1s linear;-webkit-transition:all 0.1s linear;-webkit-transition:all 0.1s linear;transition:all 0.1s linear;}/*!sc*/
# .bJzgFm .FiltersHeader-Options-Span .chevron.rotate{-moz-transform:rotate(180deg);-webkit-transform:rotate(180deg);-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}/*!sc*/
# .bJzgFm .FiltersHeader-Close{position:absolute;top:0.5rem;right:1.2rem;}/*!sc*/
# .bJzgFm .FiltersHeader-Clear{position:absolute;left:1.2rem;bottom:0;-webkit-text-decoration:underline;text-decoration:underline;cursor:pointer;}/*!sc*/
# .bJzgFm .FiltersHeader-Clear.disabled{color:gray;cursor:default;}/*!sc*/
# data-styled.g47[id="ProductsGridstyled__FiltersStyled-sc-10ok271-2"]{content:"bJzgFm,"}/*!sc*/
# .ipajxH .CustomSelect .MuiSelect-root{color:white !important;}/*!sc*/
# .ipajxH .CustomSelect svg{color:white;}/*!sc*/
# .ipajxH .MuiSelect-select{color:white;}/*!sc*/
# data-styled.g55[id="StoreSelectstyled__StoreSelectStyles-sc-1vrqe9j-0"]{content:"ipajxH,"}/*!sc*/
# *{-webkit-overflow-scrolling:touch;box-sizing:border-box;font-family:'neue-haas-grotesk-text',sans-serif;}/*!sc*/
# :root{font-size:1.388888vw;}/*!sc*/
# @media screen and (min-width:1440px){:root{font-size:20px;}}/*!sc*/
# html,body{width:100%;height:100%;}/*!sc*/
# html{-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;}/*!sc*/
# html body{display:block;}/*!sc*/
# body{margin:0;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;}/*!sc*/
# h1,h2{font-weight:unset;}/*!sc*/
# input:focus,textarea:focus{outline:none !important;}/*!sc*/
# button:focus{outline:none;}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# a:visited{color:inherit;}/*!sc*/
# ...
# <p>Escoger las <strong>gafas graduadas</strong> correctas es esencial para ver el mundo de otra manera y, además, marcando estilo. En Opticalia te ayudamos a dar en el clavo. ¡Renueva tu look!</p>
# <h2>Tenemos las gafas graduadas de marca que están de moda</h2>
# <p>En <strong>Opticalia</strong> te traeremos las gafas graduadas con ofertas que se adaptan a tus necesidades para que puedas <strong>cuidar tu mirada</strong> como mereces. Las <a href="https://www.opticalia.com/es/graduadas/graduadas-mujer">gafas graduadas de mujer</a> se convertirán en tu complemento estrella, con ellas podrás ver cada situación con claridad mientras luces las últimas tendencias en tu rostro. Porque la eficiencia no está reñida con el buen gusto.</p>
# <p>Si lo que buscas son gafas graduadas online para hombre, también ponemos a tu disposición los productos que mejor saben proteger tus ojos y sacar su potencial. De la mano de las <a href="https://www.opticalia.com/es/marcas">marcas de gafas</a> más prestigiosas podrás encontrar el <strong>modelo que mejor te sienta</strong> mientras renuevas tu particular forma de ver el mundo.</p>
# <p>Durante la época de verano, las <strong>miradas más sensibles</strong> necesitan un extra de protección para que el sol no deslumbre a cada paso. Para ello, apuesta por las gafas de sol graduadas que reúnen estilo y funcionalidad en un solo modelo. Tu accesorio imprescindible de la temporada.</p>
# <h2>Conoce las últimas tendencias en gafas graduadas</h2>
# <p>La salud de tus ojos es crucial y merece ser mimada cada día. Sin embargo, en Opticalia también tenemos en cuenta que tus gafas graduadas serán <strong>tu carta de presentación</strong> al mundo y acompañarán a tu rostro en cada gesto, en cada aventura y en los momentos más importantes de tu vida. Por eso, nos encargamos de ofrecerte <strong>la última moda en gafas graduadas</strong> para que tu identidad también se refleje en ellas.</p>
# <p>Los modelos que mejor te sientan en colores vibrantes, discretos o sofisticados, diferentes posibilidades que se ajustan a las <strong>tendencias</strong> y que te permitirán decidir cómo enmarcar tus miradas más seductoras. Para completar el look y que puedas ser más tú que nunca, echa un vistazo a los <a href="https://www.opticalia.com/es/accesorios">accesorios para gafas graduadas</a> de último modelo: el detalle que pone el broche final a tu estilo.</p>
# <p>Los diseños femeninos te seducirán con <strong>sus tonos a la última y las monturas</strong> que más se llevan este año, mientras que las <a href="https://www.opticalia.com/es/graduadas/graduadas-hombre">tendencias de gafas graduadas de hombre</a> se abren paso para convertirte en un auténtico galán o darte este estilo urbano que tanto te representa. En ellas puedes encontrar tu mejor versión.</p>
# <h2>Cuáles son las gafas graduadas más adecuadas a tu rostro</h2>
# <p>Escoger tus gafas graduadas perfectas significa prestar atención a cada detalle, pues sus formas y colores deben <strong>ofrecer a tu rostro armonía e identidad</strong>. En este proceso tendrás que tomar en cuenta el tono, que resulte lo más favorecedor posible; la forma, que encaje con tu rostro para un acabado perfecto y el tamaño, para que te queden como si estuvieran hechas a medida para ti.</p>
# <p><strong>El material de la montura puede ser determinante</strong>, ya que ofrecerá la resistencia necesaria para que tengan una vida muy larga, mientras que, a la vez, resultan confortables. Que se posen sobre tu nariz sin que casi las notes y se conviertan en una parte más de ti.</p>
# <p>¿Cómo saber <strong>qué sienta mejor</strong> a tu rostro y puede sacar todo tu potencial? Si tienes un rostro con forma cuadrada te sorprenderá lo que las gafas ovaladas o redondas pueden hacer por ti, pues suavizarán tus rasgos y aportarán equilibrio. Son formas que debes evitar si tienes el rostro redondeado, mientras que, las personas con un perfil triangulado, sacarán su mejor versión con las monturas estilo mariposa.</p>
# <p>¡Cambia de gafas graduadas y reinventa tu imagen!</p>
# </div></div><div class="Footerstyled__FooterStyles-sc-lybkub-0 ibuIrn Footer"><div class="Footer-Wrap"><div class="Footer-Content"><div class="Footer-Row"><p class="Footer-Row-Title">¿Te ayudamos?</p><a href="/es/faq" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">FAQs</p></a><a href="/es/condiciones#envios" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Envíos</p></a><a href="/es/condiciones#devoluciones" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Devoluciones</p></a><a href="/es/pedir-cita" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Petición de citas</p></a><a href="/es/promociones-vigentes" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Promociones vigentes</p></a><a href="/es/condiciones" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Condiciones de compra</p></a><a href="/es/contacto" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Contacto</p></a></div><div class="Footer-Row"><p class="Footer-Row-Title">Mi cuenta</p><a href="/es#login" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Iniciar sesión</p></a><a href="/es/register" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Registrarme</p></a><a href="/es" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Dirección de envío</p></a><a href="/es" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Historial de pedidos</p></a></div><div class="Footer-Row"><p class="Footer-Row-Title">Sobre nosotros</p><a href="/es/tiendas" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Tiendas</p></a><a href="https://opticaliaempleo.com/" hreflang="es-es" rel="alternate" target="_BLANK"><p class="Footer-Row-Item">Trabaja con nosotros</p></a><a href="/es/asociados" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Asocia tu Óptica</p></a><a href="https://www.optinet.es" hreflang="es-es" rel="alternate" target="_BLANK"><p class="Footer-Row-Item">Asociados Área Privada</p></a></div><div class="Footer-Row"><p class="Footer-Row-Title">Opticalia</p><a href="/es/sol-2x1" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">2x1 Gafas de Sol</p></a><a href="/es/audiologia" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">AUDIOCALIA</p></a><a href="/es/graduadas" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Gafas graduadas</p></a><a href="/es/sol" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Gafas de sol</p></a><a href="/es/lentillas" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Lentillas</p></a><a href="/es/marcas" hreflang="es-es" rel="alternate" target=""><p class="Footer-Row-Item">Marcas exclusivas</p></a></div><div class="Footer-StoreSelect"><p>Estás comprando en:</p><div class="StoreSelectstyled__StoreSelectStyles-sc-1vrqe9j-0 ipajxH StoreSelect"><div class="CustomSelectstyled__CustomSelectStyles-sc-121m7uf-0 inxQJr CustomSelect"><div class="CustomSelect-Wrap"><style data-emotion="css-global 1prfaxn">@-webkit-keyframes mui-auto-fill{from{display:block;}}@keyframes mui-auto-fill{from{display:block;}}@-webkit-keyframes mui-auto-fill-cancel{from{display:block;}}@keyframes mui-auto-fill-cancel{from{display:block;}}</style><style data-emotion="css 1v4ccyo">.css-1v4ccyo{font-family:"Roboto","Helvetica","Arial",sans-serif;font-weight:400;font-size:1rem;line-height:1.4375em;letter-spacing:0.00938em;color:rgba(0, 0, 0, 0.87);box-sizing:border-box;position:relative;cursor:text;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;border-radius:4px;}.css-1v4ccyo.Mui-disabled{color:rgba(0, 0, 0, 0.38);cursor:default;}.css-1v4ccyo:hover .MuiOutlinedInput ...
#           var oct8ne = document.createElement("script");
#           oct8ne.server = "backoffice-eu.oct8ne.com/";
#           oct8ne.type = "text/javascript";
#           oct8ne.async = true;
#           oct8ne.license = "AD9EF5241AF856749DA601DF43BE6CF7";
#           oct8ne.src = (document.location.protocol == "https:" ? "https://" : "http://") + "static-eu.oct8ne.com/api/v2/oct8ne-api-2.3.js?" + (Math.round(new Date().getTime() / 86400000));
#           oct8ne.locale = "es-ES";
#           oct8ne.baseUrl = "https://www.opticalia.com";
#           var s = document.getElementsByTagName("script")[0];
#           s.parentNode.insertBefore(oct8ne, s);
#         </script></div><script id="__NEXT_DATA__" type="application/json">{"props":{"appProps":{"route":{"isBrowser":false,"baseUrl":"https://www.opticalia.com","fullUrl":"https://www.opticalia.com/es/graduadas","pathname":"/es/graduadas"},"countryCodeByIp":"ES"},"__N_SSP":true,"pageProps":{"pageType":"category","template":"main","data":{"products":{"total_count":402,"items":[{"name":"BAY","commercial_name":"BAY","sku":"MNG5675-ES","url_key":"bay-mng5675-es","badge":null,"color":null,"manufacturer":95,"special_price":null,"special_from_date":null,"special_to_date":null,"thumbnail":{"url":"https://magento.opticalia.com/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/m/n/mng567520_1.png","label":"BAY NARANJA"},"price_range":{"minimum_price":{"final_price":{"value":104.9,"currency":"EUR"},"discount":{"amount_off":0,"percent_off":0},"regular_price":{"value":104.9,"currency":"EUR"}}},"configurable_options":[{"label":"Color","attribute_code":"color","values":[{"label":"CAREY","uid":"Y29uZmlndXJhYmxlLzkzLzc1","swatch_data":{"value":"#633a34"}},{"label":"NARANJA","uid":"Y29uZmlndXJhYmxlLzkzLzk2","swatch_data":{"value":"#ff8000"}}]}],"variants":[{"attributes":[{"value_index":96,"code":"color","label":"NARANJA","uid":"Y29uZmlndXJhYmxlLzkzLzk2"}],"product":{"sku":"MNG567519-ES","stock_status":"IN_STOCK","color":96,"name":"BAY NARANJA","commercial_name":"BAY","thumbnail":{"url":"https://magento.opticalia.com/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/m/n/mng567519.png","label":"BAY NARANJA"},"price_range":{"minimum_price":{"final_price":{"value":104.9,"currency":"EUR"},"discount":{"amount_off":0,"percent_off":0},"regular_price":{"value":104.9,"currency":"EUR"}}}}},{"attributes":[{"value_index":75,"code":"color","label":"CAREY","uid":"Y29uZmlndXJhYmxlLzkzLzc1"}],"product":{"sku":"MNG567520-ES","stock_status":"IN_STOCK","color":75,"name":"BAY CAREY","commercial_name":"BAY","thumbnail":{"url":"https://magento.opticalia.com/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/m/n/mng567520.png","label":"BAY CAREY"},"price_range":{"minimum_price":{"final_price":{"value":104.9,"currency":"EUR"},"discount":{"amount_off":0,"percent_off":0},"regular_price":{"value":104.9,"currency":"EUR"}}}}}]},{"name":"HYACINTH","commercial_name":"HYACINTH","sku":"VTG5623-ES","url_key":"hyacinth-vtg5623-es","badge":null,"color":null,"manufacturer":106,"special_price":null,"special_from_date":null,"special_to_date":null,"thumbnail":{"url":"https://magento.opticalia.com/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/v/t/vtg562326.png","label":"HYACINTH ROSA"},"price_range":{"minimum_price":{"final_price":{"value":124.9,"currency":"EUR"},"discount":{"amount_off":0,"percent_off":0},"regular_price":{"value":124.9,"currency":"EUR"}}},"configurable_options":[{"label":"Color","attribute_code":"color","values":[{"label":"Azul","uid":"Y29uZmlndXJhYmxlLzkzLzIx","swatch_data":{"value":"#0022ff"}},{"label":"ROSA","uid":"Y29uZmlndXJhYmxlLzkzLzU4","swatch_data":{"value":"#ff0080"}},{"label":"VERDE","uid":"Y29uZmlndXJhYmxlLzkzLzg3","swatch_data":{"value":"#32cd32"}}]}],"variants":[{"attributes":[{"value_index":58,"code":"color","label":"ROSA","uid":"Y29uZmlndXJhYmxlLzkzLzU4"}],"product":{"sku":"VTG562326-ES","stock_status":"IN_STOCK","color":58,"name":"HYACINTH ROSA","commercial_name":"HYACINTH","thumbnail":{"url":"https://magento.opticalia.com/media/catalog/product/cache/e4be6767ec9b37c1ae8637aee2f57a6a/v/t/vtg562326.png","label":"HYACINTH ROSA"},"price_range":{"minimum_price":{"final_price":{"value":124.9,"currency":"EUR"},"discount":{"amount_off":0,"percent_off":0},"regular_price":{"value":124.9,"currency":"EUR"}}}}},{"attributes":[{"value_index":21,"code":"color","label":"Azul","uid":"Y29uZmlndXJhYmxlLzkzLzIx"}],"product":{"sku":"VTG562372-ES","stock_status":"IN_STOCK","color":21,"name":"HYACINTH AZUL","commercial_name":"HYACINTH","thumbnail":{"url":"https://magento.opticalia.com/media/catalog/product/cache/e4be6767ec9b37c ...

# %%
lc_ou = {"categoria":[],
         "producto":[],
         "remplazo":[],
         "precio":[]}

# %%
def get_lc_gafas_ou(url): 
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    
    all_lentillas = soup.find_all("li",class_="item last")
    
    lc_ou = {"nombre_completo":[],
        "categoria":[],
         "producto":[],
         "reemplazo":[],
         "precio":[]}
    for lentilla in all_lentillas:
        lc_ou["nombre_completo"].append((lentilla.find("a").get("data-name")))
        lc_ou["categoria"].append((lentilla.find("a").get("data-category")))
        lc_ou["producto"].append((lentilla.find("a").get("data-brand")))
        lc_ou["reemplazo"].append((lentilla.find("a").get("data-list")))
        lc_ou["precio"].append((lentilla.find("a").get("data-price")))
    df_lc = pd.DataFrame(lc_ou)
    df_lc.to_csv("Data/csv_scrap/" + url.split("/")[-1] + ".csv")

# %%
pagina_lc_gafas_liq = get_lc_gafas_ou("https://www.opticauniversitaria.es/lentillas/diarias")

# %%
def get_gafas_greyhounders(url): 
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    
    gre_gf_lc = soup.find_all("li",class_="grid__item col-6 col-sm-4")
    
    lc__gf_grey = {"nombre_completo":[],
                    "precio":[]}
    for prod in gre_gf_lc:
        lc__gf_grey["nombre_completo"].append((prod.find("span").get_text("visually-hidden")))
        lc__gf_grey["precio"].append((prod.find("span",class_="price-item price-item--regular")).get_text())
    df_gf_lc = pd.DataFrame(lc__gf_grey)
    df_gf_lc.to_csv("Data/csv_scrap/" + url.split("/")[-1] + ".csv")

# %%
def get_lc_greyhounders(url): 
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    
    gre_gf_lc = soup.find_all("div",class_="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 iFOwmD ProductCard")
    
    lc__gf_grey = {"nombre_completo":[],
                    "precio":[]}
    for prod in gre_gf_lc:
        lc__gf_grey["nombre_completo"].append((prod.find("span").get_text("visually-hidden")))
        lc__gf_grey["precio"].append((prod.find("span",class_="price-item price-item--sale")).get_text())
    df_gf_lc = pd.DataFrame(lc__gf_grey)
    df_gf_lc.to_csv("Data/csv_scrap/" + url.split("/")[-1] + ".csv")

# %%
pag_grey_gaf = get_gafas_greyhounders("https://greyhounders.com/collections/toda-la-coleccion-graduadas")

# %%
pag_grey_lc = get_lc_greyhounders("https://greyhounders.com/collections/lentillas")

# %%
def get_lc_gafas_opticalia(url): 
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    
    all_lentillas = soup.find_all("div",class_="ProductCardstyled__ProductCardStyles-sc-1yccf7l-0 kDLTuk ProductCard")
    
    lc_ou = {"nombre_completo":[],
            "categoria":[],
            "producto":[],
            "reemplazo":[],
            "precio":[]}
    for lentilla in all_lentillas:
        lc_ou["nombre_completo"].append((lentilla.find("p",class_="ProductCard-Info-Line1-Title")).get_text())
        lc_ou["categoria"].append("Lentillas")
        lc_ou["producto"].append("Liquidos")
        lc_ou["reemplazo"].append("Mensuales")
        lc_ou["precio"].append((lentilla.find("div",class_="ProductCard-Info-Line1-Price")).get_text())
    df_lc = pd.DataFrame(lc_ou)
    df_lc.to_csv("Data/csv_scrap/grad.csv")

# %%
pag_opticalia_gafas = get_lc_gafas_opticalia("https://www.opticalia.com/es/lentillas/liquidos")

# %%
def get_lc_gafas_afflelou(url): 
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    
    all_lentillas = soup.find_all("div",class_="col-lg-4 col-md-6 col-12 py-2 px-3")
    
    lc_ou = {"nombre_completo":[],
            "categoria":[],
            "precio":[]}
    for lentilla in all_lentillas:
        lc_ou["nombre_completo"].append((lentilla.find("span",class_="c-product__description-item u-hyphen-initial d-block text-silver text-uppercase")).get_text())
        lc_ou["categoria"].append(lentilla.find("span",class_="c-product__description-item u-hyphen-initial d-block text-light").get_text())
        lc_ou["precio"].append((lentilla.find("p",class_="c-product__description-item c-product__description-item__price mt-2 mb-0 mx-0 text-silver is-active")).get_text("span"))
    df_lc = pd.DataFrame(lc_ou)
    df_lc.to_csv("Data/csv_scrap/grad.csv")

# %%
pag_opticalia_gafas = get_lc_gafas_afflelou("https://www.afflelou.es/gafas-graduadas/afflelou/?page=6&sort=price")
